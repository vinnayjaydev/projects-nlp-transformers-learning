# %%
# !pip install fastapi
# !pip install uvicorn
# !pip install python-multipart
# !pip install sentence-transformers
# !pip install faiss-cpu
# !pip install pdfplumber

# %%
import pickle

with open(
    r"D:\Books\projects-nlp-transformers-learning\projects\06-resume-search\notebooks\indexes\resume_metadata.pkl",
    "rb",
) as f:
    metadata = pickle.load(f)

print(type(metadata))
print(metadata.keys())
# Out:
# <class 'dict'>
# dict_keys(['file_names'])
