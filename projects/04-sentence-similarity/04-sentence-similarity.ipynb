# %%
# ==========================================================
# Notebook 1: Introduction to Sentence Similarity
# ==========================================================

print("Notebook 1: Introduction to Sentence Similarity")
# Out:
# Notebook 1: Introduction to Sentence Similarity

# %%
sentence_1 = "The dog chased the cat."
sentence_2 = "A hound pursued the feline."
sentence_3 = "I am eating pizza."

print("Sentence 1:", sentence_1)
print("Sentence 2:", sentence_2)
print("Sentence 3:", sentence_3)
# Out:
# Sentence 1: The dog chased the cat.
# Sentence 2: A hound pursued the feline.
# Sentence 3: I am eating pizza.

# %%
examples = [
    ["The dog chased the cat.", "A hound pursued the feline."],
    ["I love machine learning.", "I enjoy studying AI."],
    ["The stock market crashed.", "I am eating pizza."],
]

for idx, pair in enumerate(examples, 1):
    print(f"\nExample {idx}")
    print("Sentence A:", pair[0])
    print("Sentence B:", pair[1])
# Out:
# Example 1
# Sentence A: The dog chased the cat.
# Sentence B: A hound pursued the feline.
#
# Example 2
# Sentence A: I love machine learning.
# Sentence B: I enjoy studying AI.
#
# Example 3
# Sentence A: The stock market crashed.
# Sentence B: I am eating pizza.

# %%
# This is NOT a real embedding.
# It is just a toy example for understanding.

embedding = [0.42, -0.15, 0.88, 0.31, -0.07]

print("Sentence Embedding:")
print(embedding)

print("\nEmbedding Dimension:", len(embedding))
# Out:
# Sentence Embedding:
# [0.42, -0.15, 0.88, 0.31, -0.07]
#
# Embedding Dimension: 5

# %%
import numpy as np

A = np.array([0.4, 0.8])
B = np.array([0.5, 0.7])
C = np.array([-0.8, -0.4])

print("Sentence A Vector:", A)
print("Sentence B Vector:", B)
print("Sentence C Vector:", C)
# Out:
# Sentence A Vector: [0.4 0.8]
# Sentence B Vector: [0.5 0.7]
# Sentence C Vector: [-0.8 -0.4]

# %%
pipeline = [
    "Input Sentence",
    "Tokenizer",
    "Embedding Model",
    "Sentence Vector",
    "Cosine Similarity",
    "Similarity Score",
]

for step_num, step in enumerate(pipeline, start=1):
    print(f"{step_num}. {step}")
# Out:
# 1. Input Sentence
# 2. Tokenizer
# 3. Embedding Model
# 4. Sentence Vector
# 5. Cosine Similarity
# 6. Similarity Score

# %%
applications = [
    "Semantic Search",
    "RAG Retrieval",
    "Question Answering",
    "Duplicate Detection",
    "Recommendation Systems",
    "Resume Matching",
]

print("Applications of Sentence Similarity:\n")

for app in applications:
    print("•", app)
# Out:
# Applications of Sentence Similarity:
#
# • Semantic Search
# • RAG Retrieval
# • Question Answering
# • Duplicate Detection
# • Recommendation Systems
# • Resume Matching

# %%
documents = [
    "Beginner guide to Artificial Intelligence",
    "Introduction to Machine Learning",
    "Learn Python programming from scratch",
    "Top 10 travel destinations",
    "Best pizza recipes",
]

scores = [0.94, 0.87, 0.76, 0.08, 0.03]

for doc, score in zip(documents, scores):
    print(f"{score:.2f}  -->  {doc}")
# Out:
# 0.94  -->  Beginner guide to Artificial Intelligence
# 0.87  -->  Introduction to Machine Learning
# 0.76  -->  Learn Python programming from scratch
# 0.08  -->  Top 10 travel destinations
# 0.03  -->  Best pizza recipes
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
