# %%
# ==========================================================
# Notebook 1: Introduction to Sentence Similarity
# ==========================================================

print("Notebook 1: Introduction to Sentence Similarity")
# Out:
# Notebook 1: Introduction to Sentence Similarity

# %%
04-sentence-similarity-1.ipynb

# %%
# Notebook 1:
# Introduction to Sentence Similarity
#                │
#                ▼
# Notebook 2:
# Cosine Similarity, Dot Product, Euclidean & Manhattan Distance
Cosine Similarity, Dot Product,
Euclidean Distance & Manhattan Distance
#                │
#                ▼
# Notebook 3:
# Building a TF-IDF Similarity Engine
#                │
#                ▼
# Notebook 4:
# Sentence-BERT (SBERT) Embeddings and Inference
#                │
#                ▼
# Notebook 5:
# Mean Pooling and Manual Embedding Extraction
#                │
#                ▼
# Notebook 6:
# Bi-Encoder vs Cross-Encoder
#                │
#                ▼
# Notebook 7:
# Pairwise Similarity Matrix & Heatmap Visualization
#                │
#                ▼
# Notebook 8:
# Building a Semantic Search Engine
#                │
#                ▼
# Notebook 9:
# FAISS / Chroma Vector Database Integration
#                │
#                ▼
# Notebook 10:
# End-to-End Sentence Similarity Engine & Visualizer
